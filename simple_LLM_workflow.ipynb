# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash')

# %%
class LLMState(TypedDict):
    question:str
    answer:str

# %%
def llm_qa(state:LLMState) -> LLMState:
    question = state['question']

    prompt = f"Answer the Given question {question}"

    answer = model.invoke(prompt).content

    state['answer'] = answer

    return state

# %%
graph = StateGraph(LLMState)

graph.add_node('llm_qa', llm_qa)

graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

workflow = graph.compile()

# %%
initial_state = {'question':'how far moon form earth'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'question': 'how far moon form earth', 'answer': 'The distance between the Earth and the Moon is not constant because the Moon orbits the Earth in an ellipse, not a perfect circle.\n\nHere are the key distances:\n\n*   **Average Distance:** Approximately **384,400 kilometers (238,855 miles)**.\n*   **Perigee (closest point):** Around **363,104 kilometers (225,623 miles)**.\n*   **Apogee (farthest point):** Around **405,696 kilometers (252,088 miles)**.\n\nTo give you a sense of scale, light from the Moon takes about **1.28 seconds** to reach Earth at its average distance.'}
