# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()

model = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash')

# %%
class BlogState(TypedDict):
    title: str
    outline:str
    content: str

# %%
def create_outline(state:BlogState) -> BlogState:
    title = state['title']

    prompt = f'generate a detail ouline for a blog {title}'

    outline = model.invoke(prompt).content

    state['outline'] = outline

    return state

# %%
def create_blog(state:BlogState) -> BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'write a detail blog on the title {title} using the following outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
initail_state = {'title':'Rise of AI in Pakistan'}

final_state = workflow.invoke(initail_state)

print(final_state['outline'])
# Out:
# Here's a detailed outline for a blog post titled "Rise of AI in Pakistan," designed to be informative, engaging, and comprehensive.
#
# ---
#
# ## Blog Post Title: The Rise of AI in Pakistan: Opportunities, Challenges, and the Road Ahead
#
# **Target Audience:** General public, students, tech enthusiasts, policymakers, investors, entrepreneurs, IT professionals in Pakistan and abroad.
#
# **Tone:** Optimistic, informative, analytical, slightly urgent (regarding the need to capitalize on opportunities).
#
# **SEO Keywords:** AI Pakistan, Artificial Intelligence Pakistan, Pakistan Tech, AI startups Pakistan, Digital Pakistan, AI policy Pakistan, Future of AI Pakistan, Tech jobs Pakistan, AI opportunities Pakistan.
#
# ---
#
# ### I. Introduction (Approx. 150-200 words)
#
# *   **A. Catchy Hook:** Start with a compelling statement about the global AI revolution and how Pakistan, despite its challenges, is uniquely positioned to be a significant player.
#     *   *Example:* "From Silicon Valley boardrooms to the bustling streets of Lahore, Artificial Intelligence (AI) is no longer a futuristic concept but a present-day reality transforming industries and lives. And in Pakistan, this wave isn't just arriving; it's rapidly gaining momentum, promising to reshape our economic and social fabric."
# *   **B. Brief Definition of AI:** A concise, easy-to-understand explanation of what AI is and why it matters (e.g., simulating human intelligence, automating tasks, data analysis, problem-solving).
# *   **C. Thesis Statement:** Clearly state the blog's purpose – to explore the burgeoning AI landscape in Pakistan, highlighting its potential, the current efforts, the hurdles it faces, and the strategic path forward.
#
# ---
#
# ### II. The Current AI Landscape in Pakistan: A Budding Ecosystem (Approx. 250-300 words)
#
# *   **A. Early Adoption & Growth:**
#     *   Describe the initial phase of AI adoption – from academic interest to nascent industry applications.
#     *   Mention the rapid acceleration in recent years.
# *   **B. Key Players & Hubs:**
#     *   **Academic Institutions:** Highlight universities leading AI research and education (e.g., NUST, FAST-NUCES, LUMS, NED, UET). Mention specialized labs or research centers.
#     *   **Startup Scene:** Showcase emerging AI startups and their innovative solutions (mention 2-3 examples if possible, e.g., in agri-tech, health-tech, e-commerce, or fintech).
#     *   **Tech Parks & Incubators:** Discuss the role of National Incubation Centers (NICs), Arfa Software Technology Park, etc., in fostering AI innovation.
#     *   **Private Sector Engagement:** Briefly touch upon larger corporations starting to integrate AI into their operations.
# *   **C. Government Initiatives & Policy:**
#     *   **National AI Policy:** Discuss the formulation and aims of Pakistan's National AI Policy – its vision for economic growth, job creation, and global competitiveness.
#     *   **Ministry of IT & Telecom:** Mention their role in promoting digital transformation and AI.
#     *   **National Center for Artificial Intelligence (NCAI):** Explain its mandate in research, development, and capacity building.
#
# ---
#
# ### III. AI Across Key Sectors in Pakistan: Transforming Potential (Approx. 350-400 words)
#
# *   **A. Agriculture:**
#     *   **Potential:** Crop yield prediction, pest and disease detection, precision farming, water management, livestock monitoring.
#     *   **Examples/Impact:** How AI can boost food security and farmer income.
# *   **B. Healthcare:**
#     *   **Potential:** Diagnostic assistance (e.g., medical imaging analysis), personalized treatment plans, drug discovery, remote patient monitoring, epidemic prediction.
#     *   **Examples/Impact:** Improving access to quality healthcare, especially in remote areas.
# *   **C. Education:**
#     *   **Potential:** Personalized learning platforms, intelligent tutoring systems, automated grading, content creation, administrative efficiency.
#     *   **Examples/Impact:** Addressing literacy gaps, making education more accessible and engaging.
# *   **D. Finance & Fintech:**
#     *   **Potential:** Fraud detection, credit scoring for the unbanked, algorithmic trading, personalized financial advice, customer service chatbots.
#     *   **Examples/Impact:** Financial inclusion, secure transactions.
# *   **E. IT & Software Exports:**
#     *   **Potential:** AI-as-a-Service, AI-powered software development, leveraging Pakistan's talent pool for global AI projects.
#     *   **Examples/Impact:** Boosting export revenues, positioning Pakistan as an AI outsourcing hub.
# *   **F. E-commerce & Logistics:**
#     *   **Potential:** Personalized recommendations, supply chain optimization, demand forecasting, last-mile delivery efficiency.
#     *   **Examples/Impact:** Enhancing customer experience, reducing operational costs.
#
# ---
#
# ### IV. Opportunities AI Presents for Pakistan (Approx. 200-250 words)
#
# *   **A. Economic Growth & Job Creation:**
#     *   New industries, high-skilled jobs, value addition to existing sectors.
#     *   Attracting foreign investment.
# *   **B. Problem Solving for Local Challenges:**
#     *   Addressing issues in public services (e.g., traffic management, disaster prediction).
#     *   Improving governance and transparency.
# *   **C. Global Competitiveness & Brand Building:**
#     *   Positioning Pakistan as a hub for AI innovation and talent.
#     *   Reducing reliance on traditional economic sectors.
# *   **D. Empowerment & Inclusion:**
#     *   Providing tools and opportunities for marginalized communities.
#     *   Bridging the digital divide.
#
# ---
#
# ### V. Navigating the Challenges: Hurdles on the Path to AI Dominance (Approx. 300-350 words)
#
# *   **A. Talent & Skills Gap:**
#     *   Lack of specialized AI researchers and engineers.
#     *   Need for robust training programs and curriculum reform.
#     *   Brain drain.
# *   **B. Infrastructure Limitations:**
#     *   Reliable and affordable high-speed internet access across the country.
#     *   Access to high-performance computing resources.
# *   **C. Data Availability & Quality:**
#     *   Lack of structured, clean, and diverse datasets relevant to Pakistan's context.
#     *   Data privacy and security concerns.
# *   **D. Funding & Investment:**
#     *   Limited venture capital and angel investment for early-stage AI startups.
#     *   Need for government incentives and public-private partnerships.
# *   **E. Ethical & Regulatory Frameworks:**
#     *   Developing clear guidelines for AI ethics, bias, accountability, and privacy.
#     *   Ensuring responsible AI development and deployment.
# *   **F. Digital Divide:**
#     *   Ensuring AI benefits reach all segments of society, not just urban elites.
#
# ---
#
# ### VI. The Road Ahead: Recommendations & Future Outlook (Approx. 200-250 words)
#
# *   **A. Strategic Investment:**
#     *   Increase public and private investment in AI research, development, and startups.
#     *   Create AI-specific grants and funding programs.
# *   **B. Education & Capacity Building:**
#     *   Revamp curricula from primary to higher education to include AI literacy.
#     *   Promote vocational training and reskilling programs for the existing workforce.
#     *   Foster industry-academia collaboration for practical training.
# *   **C. Data Infrastructure & Governance:**
#     *   Develop national data policies and platforms.
#     *   Promote data sharing while ensuring privacy and security.
# *   **D. Fostering Collaboration:**
#     *   Strengthen ties between government, academia, industry, and international partners.
#     *   Encourage cross-sectoral AI applications.
# *   **E. Ethical AI Development:**
#     *   Proactively develop and implement ethical guidelines and regulatory frameworks.
#     *   Focus on AI solutions that are inclusive and address societal needs.
# *   **F. Optimistic Outlook:** Reiterate that despite challenges, Pakistan has the potential to become a significant regional player in AI with concerted effort and strategic planning.
#
# ---
#
# ### VII. Conclusion (Approx. 100-150 words)
#
# *   **A. Recap Thesis:** Briefly summarize the key points – AI's rapid rise in Pakistan, its immense potential, and the critical challenges.
# *   **B. Final Thought/Call to Action:** End with an inspiring message about seizing the moment. Encourage readers (policymakers, students, entrepreneurs) to contribute to Pakistan's AI journey.
#     *   *Example:* "The rise of AI in Pakistan isn't just a technological shift; it's a national imperative. By strategically investing in talent, infrastructure, and ethical frameworks, Pakistan can unlock unprecedented opportunities, leapfrog development challenges, and secure its place in the global digital economy. The time to act is now."
#
# ---
